# %%
import pandas as pd
import scipy.stats
import numpy as np
import gspread

# %%
gc = gspread.oauth()

sh = gc.open_by_url('https://docs.google.com/spreadsheets/d/1KlVfVCuob9hinhDu_Pvk6Z1kctlbnA2Ct14gnpVcx6U/edit#gid=0')

ws = sh.worksheet('Data')

df = pd.DataFrame(ws.get_all_records())
df.head()
# Out:
#   abbreviation  ahead/behind  at_bats  average_batter_age  \
# 0          SFG            -1     2365                30.7
# 1          LAD            -3     2391                29.0
# 2          HOU            -4     2457                28.9
# 3          OAK             4     2369                29.9
# 4          BOS             4     2446                28.2
#
#    average_pitcher_age  away_losses away_record  away_wins  balks  \
# 0                 29.6           16       22-16         22      4
# 1                 29.0           15       21-15         21      2
# 2                 28.7           15       17-15         17      1
# 3                 30.2           11       19-11         19      1
# 4                 29.9           12       23-12         23      2
#
#    bases_on_balls  ...  wild_pitches  win_percentage  wins  \
# 0             280  ...            16           0.639    46
# 1             309  ...            24           0.620    44
# ...

# %%
r2_df_dict = {}

for col in df.columns[3:]:
    correlation_matrix = np.corrcoef(df['wins'],col)
    correlation_xy = correlation_matrix[0,1]
    r2 = correlation_xy**2
    print(col + ' ' + ' ' + str(r2))
    if col not in r2_df_dict.keys():
        r2_df_dict[col] = r2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-17c551e9b99e> in <module>
#       2
#       3 for col in df.columns[3:]:
# ----> 4     correlation_matrix = np.corrcoef(df['wins'],col)
#       5     correlation_xy = correlation_matrix[0,1]
#       6     r2 = correlation_xy**2
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2549         warnings.warn('bias and ddof have no effect and are deprecated',
#    2550                       DeprecationWarning, stacklevel=3)
# -> 2551     c = cov(x, y, rowvar)
#    2552     try:
#    2553         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
# ...

# %%
from sklearn.metrics import r2_score

r2_score(df[7], df[8])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 7
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-fe68a772b499> in <module>
#       1 from sklearn.metrics import r2_score
# ...
