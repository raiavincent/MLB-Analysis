# %%
import pandas_gbq as pdgbq
import pandas as pd

# %%
pitch_query = '''
SELECT
  pd.pitch_type,
  pr.pitch_name,
  ROUND(AVG(pd.release_speed),2) AS avg_speed,
  FORMAT("%'d",COUNT(*)) AS outs
FROM
  `valuesheet.MLB.hitting_data` AS hd
LEFT JOIN
  `valuesheet.MLB.pitching_view` AS pd
ON
  pd.pitch_id = hd.pitch_id
LEFT JOIN
  `valuesheet.MLB.pitch_ref` AS pr
ON
  pd.pitch_type = pr.pitch_type
WHERE
  hd.events = 'strikeout'
  AND pd.type IN('S')
  AND pd.pitch_type IS NOT NULL
GROUP BY
  pd.pitch_type,
  pr.pitch_name
ORDER BY
  AVG(pd.release_speed) DESC
'''

# %%
pitches = pdgbq.read_gbq(query=pitch_query,project_id='valuesheet')
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~\anaconda3\envs\mlb_env\lib\site-packages\pandas_gbq\gbq.py in _download_results(self, query_job, max_results, progress_bar_type, user_dtypes)
#     522         try:
# --> 523             query_job.result()
#     524             # Get the table schema, so that we can list rows.
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\cloud\bigquery\job\query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1371
# -> 1372             do_get_result()
#    1373
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     282             )
# --> 283             return retry_target(
#     284                 target,
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189         try:
# --> 190             return target()
#     191
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\cloud\bigquery\job\query.py in do_get_result()
#    1361
# -> 1362                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1363
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\cloud\bigquery\job\base.py in result(self, retry, timeout)
#     712         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 713         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     714
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\google\api_core\future\polling.py in result(self, timeout, retry)
#     136             # Pylint doesn't recognize that this is valid in this case.
# --> 137             raise self._exception
#     138
#
# NotFound: 404 Not found: Table valuesheet:MLB.statcast was not found in location US
#
# (job ID: a683cca2-6a40-4a0f-86ed-d6e70ea150dc)
#
#           -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |
#    1:
#    2:SELECT
#    3:  pd.pitch_type,
#    4:  pr.pitch_name,
#    5:  ROUND(AVG(pd.release_speed),2) AS avg_speed,
#    6:  FORMAT("%'d",COUNT(*)) AS outs
#    7:FROM
#    8:  `valuesheet.MLB.hitting_data` AS hd
#    9:LEFT JOIN
#   10:  `valuesheet.MLB.pitching_view` AS pd
#   11:ON
#   12:  pd.pitch_id = hd.pitch_id
#   13:LEFT JOIN
#   14:  `valuesheet.MLB.pitch_ref` AS pr
#   15:ON
#   16:  pd.pitch_type = pr.pitch_type
#   17:WHERE
#   18:  hd.events = 'strikeout'
#   19:  AND pd.type IN('S')
#   20:  AND pd.pitch_type IS NOT NULL
#   21:GROUP BY
#   22:  pd.pitch_type,
#   23:  pr.pitch_name
#   24:ORDER BY
#   25:  AVG(pd.release_speed) DESC
#     |    .    |    .    |    .    |    .    |
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-3-17d5c74e7eb3> in <module>
# ----> 1 pitches = pdgbq.read_gbq(query=pitch_query,project_id='valuesheet')
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\pandas_gbq\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes)
#     850     )
#     851
# --> 852     final_df = connector.run_query(
#     853         query,
#     854         configuration=configuration,
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, max_results, progress_bar_type, **kwargs)
#     475
#     476         dtypes = kwargs.get("dtypes")
# --> 477         return self._download_results(
#     478             query_reply,
#     479             max_results=max_results,
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\pandas_gbq\gbq.py in _download_results(self, query_job, max_results, progress_bar_type, user_dtypes)
#     537             )
#     538         except self.http_error as ex:
# --> 539             self.process_http_error(ex)
#     540
#     541         if df.empty:
#
# ~\anaconda3\envs\mlb_env\lib\site-packages\pandas_gbq\gbq.py in process_http_error(ex)
#     378         # <https://cloud.google.com/bigquery/troubleshooting-errors>`__
#     379
# --> 380         raise GenericGBQException("Reason: {0}".format(ex))
#     381
#     382     def run_query(
#
# GenericGBQException: Reason: 404 Not found: Table valuesheet:MLB.statcast was not found in location US
#
# (job ID: a683cca2-6a40-4a0f-86ed-d6e70ea150dc)
#
#           -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |
#    1:
#    2:SELECT
#    3:  pd.pitch_type,
#    4:  pr.pitch_name,
#    5:  ROUND(AVG(pd.release_speed),2) AS avg_speed,
#    6:  FORMAT("%'d",COUNT(*)) AS outs
#    7:FROM
#    8:  `valuesheet.MLB.hitting_data` AS hd
#    9:LEFT JOIN
#   10:  `valuesheet.MLB.pitching_view` AS pd
#   11:ON
#   12:  pd.pitch_id = hd.pitch_id
#   13:LEFT JOIN
#   14:  `valuesheet.MLB.pitch_ref` AS pr
#   15:ON
#   16:  pd.pitch_type = pr.pitch_type
#   17:WHERE
#   18:  hd.events = 'strikeout'
#   19:  AND pd.type IN('S')
#   20:  AND pd.pitch_type IS NOT NULL
#   21:GROUP BY
#   22:  pd.pitch_type,
#   23:  pr.pitch_name
#   24:ORDER BY
#   25:  AVG(pd.release_speed) DESC
#     |    .    |    .    |    .    |    .    |

# %%
pitches.head(15)
# Out:
#    pitch_type       pitch_name  avg_speed    outs
# 0          FF  4-Seam Fastball      94.18  80,298
# 1          FT  2-Seam Fastball      93.12  13,234
# 2          SI           Sinker      92.94  17,342
# 3          FC           Cutter      88.79  14,185
# 4          FO         Forkball      86.62      88
# 5          FS     Split-Finger      85.56   6,332
# 6          SL           Slider      85.00  63,533
# 7          CH         Changeup      84.56  28,658
# 8          KC    Knuckle Curve      82.09   9,204
# 9          CU        Curveball      79.40  28,563
# 10         SC        Screwball      78.69       7
# 11         KN      Knuckleball      77.16     530
# 12         FA         Fastball      76.37      17
# 13         CS        Curveball      69.77      67
# 14         EP           Eephus      67.83      91
